# %%
# !pip install spacy==2.1.0  # Install a compatible version for NeuralCoref
# !pip install srsly==1.0.5  # Install a compatible version for NeuralCoref
# Out:
# ...
#      |████████████████████████████████| 27.7 MB 5.1 MB/s eta 0:00:01    |█▊                              | 1.5 MB 2.2 MB/s eta 0:00:12     |██████████████████▊             | 16.2 MB 911 kB/s eta 0:00:13     |████████████████████▋           | 17.8 MB 220 kB/s eta 0:00:45     |███████████████████████████▋    | 23.9 MB 979 kB/s eta 0:00:04
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python /private/var/folders/v1/k0cjm9512hj0pfqzm2w1p1y80000gn/T/pip-standalone-pip-ayopd61x/__env_pip__.zip/pip install --ignore-installed --no-user --prefix /private/var/folders/v1/k0cjm9512hj0pfqzm2w1p1y80000gn/T/pip-build-env-ojt5z30k/overlay --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'wheel>0.32.0.<0.33.0' Cython 'cymem>=2.0.2,<2.1.0' 'preshed>=2.0.1,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' thinc==7.0.0.dev6
#        cwd: None
#   Complete output (339 lines):
# ...

# %%
# !git clone https://github.com/huggingface/neuralcoref.git
# %cd neuralcoref
# !pip install -r requirements.txt  # Install required packages
# !pip install -e .  # Install NeuralCoref from the local clone
# Out:
# xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
# [Errno 2] No such file or directory: 'neuralcoref'
# /Users/architaggarwal/Documents/Thesis ka kaam /Code
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ERROR: File "setup.py" or "setup.cfg" not found. Directory cannot be installed in editable mode: /Users/architaggarwal/Documents/Thesis ka kaam /Code
